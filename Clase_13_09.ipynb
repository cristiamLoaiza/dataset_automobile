# %%
import pandas as pd

# %%
link = "Datasets/Automobile_data.csv"

# %%
dataset =  pd.read_csv(link)

# %%
dataset.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
dataset.tail(10)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 195         -1                74  volvo       gas        std         four
# 196         -2               103  volvo       gas        std         four
# 197         -1                74  volvo       gas        std         four
# 198         -2               103  volvo       gas      turbo         four
# 199         -1                74  volvo       gas      turbo         four
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 195      wagon          rwd           front       104.3  ...          141
# ...

# %%
dataset.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
dataset.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
dataset.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
dataset["drive-wheels"].value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drive-wheels, dtype: int64

# %%
dataset["drive-wheels"].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
dataset["fuel-type"].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
dataset["drive-wheels"].value_counts().plot(kind="pie",autopct="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='drive-wheels'>

# %%
dataset["fuel-type"].value_counts().plot(kind="pie",autopct="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='fuel-type'>

# %%
dataset["make"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='make'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(14,5))
dataset["make"].value_counts().plot(kind="bar")
plt.title("Marcas de carros")
# Out:
# Text(0.5, 1.0, 'Marcas de carros')

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# %%
sns.boxplot(x = dataset["drive-wheels"],y = dataset["width"])
# Out:
# <AxesSubplot:xlabel='drive-wheels', ylabel='width'>

# %%
dataset.groupby(["drive-wheels"]).width.describe()
# Out:
#               count       mean       std   min   25%   50%   75%   max
# drive-wheels
# 4wd             9.0  65.211111  1.412838  63.6  63.8  65.4  65.4  67.9
# fwd           120.0  65.057500  1.576650  60.3  63.8  64.6  66.3  71.4
# rwd            76.0  67.332895  2.255446  61.8  65.6  67.2  68.4  72.3

# %%
dataset.width
# Out:
# 0      64.1
# 1      64.1
# 2      65.5
# 3      66.2
# 4      66.4
#        ...
# 200    68.9
# 201    68.8
# 202    68.9
# 203    68.9
# 204    68.9
# Name: width, Length: 205, dtype: float64

# %%
dataset.plot(kind="scatter",x="engine-size",y="width",title="Grafica de dispersion")
# Out:
# <AxesSubplot:title={'center':'Grafica de dispersion'}, xlabel='engine-size', ylabel='width'>

# %%
dataset["engine-size"].unique()
# Out:
# array([130, 152, 109, 136, 131, 108, 164, 209,  61,  90,  98, 122, 156,
#         92,  79, 110, 111, 119, 258, 326,  91,  70,  80, 140, 134, 183,
#        234, 308, 304,  97, 103, 120, 181, 151, 194, 203, 132, 121, 146,
#        171, 161, 141, 173, 145], dtype=int64)
