# %%
link = "Data/car/imports_85_data.csv"

# %%
import pandas as pd

# %%
data = pd.read_csv(link)

# %%
data.head(20)
# Out:
#     column_a  column_b     column_c column_d column_e column_f     column_g  \
# 0          3       NaN  alfa-romero      gas      std      two  convertible
# 1          3       NaN  alfa-romero      gas      std      two  convertible
# 2          1       NaN  alfa-romero      gas      std      two    hatchback
# 3          2     164.0         audi      gas      std     four        sedan
# 4          2     164.0         audi      gas      std     four        sedan
# 5          2       NaN         audi      gas      std      two        sedan
# 6          1     158.0         audi      gas      std     four        sedan
# 7          1       NaN         audi      gas      std     four        wagon
# 8          1     158.0         audi      gas    turbo     four        sedan
# 9          0       NaN         audi      gas    turbo      two    hatchback
# 10         2     192.0          bmw      gas      std      two        sedan
# ...

# %%
data.tail()
# Out:
#      column_a  column_b column_c column_d column_e column_f column_g column_h  \
# 200        -1      95.0    volvo      gas      std     four    sedan      rwd
# 201        -1      95.0    volvo      gas    turbo     four    sedan      rwd
# 202        -1      95.0    volvo      gas      std     four    sedan      rwd
# 203        -1      95.0    volvo   diesel    turbo     four    sedan      rwd
# 204        -1      95.0    volvo      gas    turbo     four    sedan      rwd
#
#     column_i  column_j  ...  column_q  column_r  column_s  column_t column_u  \
# 200    front     109.1  ...       141      mpfi      3.78      3.15      9.5
# 201    front     109.1  ...       141      mpfi      3.78      3.15      8.7
# 202    front     109.1  ...       173      mpfi      3.58      2.87      8.8
# 203    front     109.1  ...       145       idi      3.01      3.40     23.0
# 204    front     109.1  ...       141      mpfi      3.78      3.15      9.5
#
# ...

# %%
data.isna().sum()
# Out:
# column_a     0
# column_b    41
# column_c     0
# column_d     0
# column_e     0
# column_f     0
# column_g     0
# column_h     0
# column_i     0
# column_j     0
# column_k     0
# column_l     0
# column_m     0
# column_n     0
# column_o     0
# column_p     0
# column_q     0
# column_r     0
# column_s     4
# column_t     4
# column_u     0
# column_v     2
# column_w     2
# column_x     0
# column_y     0
# column_z     4
# dtype: int64

# %%
datana = data.dropna(axis = 0)

# %%
datana.head()
# Out:
#     column_a  column_b column_c column_d column_e column_f column_g column_h  \
# 3          2     164.0     audi      gas      std     four    sedan      fwd
# 4          2     164.0     audi      gas      std     four    sedan      4wd
# 6          1     158.0     audi      gas      std     four    sedan      fwd
# 8          1     158.0     audi      gas    turbo     four    sedan      fwd
# 10         2     192.0      bmw      gas      std      two    sedan      rwd
#
#    column_i  column_j  ...  column_q  column_r  column_s  column_t column_u  \
# 3     front      99.8  ...       109      mpfi      3.19       3.4     10.0
# 4     front      99.4  ...       136      mpfi      3.19       3.4      8.0
# 6     front     105.8  ...       136      mpfi      3.19       3.4      8.5
# 8     front     105.8  ...       131      mpfi      3.13       3.4      8.3
# 10    front     101.2  ...       108      mpfi      3.50       2.8      8.8
#
# ...

# %%
datana.tail()
# Out:
#      column_a  column_b column_c column_d column_e column_f column_g column_h  \
# 200        -1      95.0    volvo      gas      std     four    sedan      rwd
# 201        -1      95.0    volvo      gas    turbo     four    sedan      rwd
# 202        -1      95.0    volvo      gas      std     four    sedan      rwd
# 203        -1      95.0    volvo   diesel    turbo     four    sedan      rwd
# 204        -1      95.0    volvo      gas    turbo     four    sedan      rwd
#
#     column_i  column_j  ...  column_q  column_r  column_s  column_t column_u  \
# 200    front     109.1  ...       141      mpfi      3.78      3.15      9.5
# 201    front     109.1  ...       141      mpfi      3.78      3.15      8.7
# 202    front     109.1  ...       173      mpfi      3.58      2.87      8.8
# 203    front     109.1  ...       145       idi      3.01      3.40     23.0
# 204    front     109.1  ...       141      mpfi      3.78      3.15      9.5
#
# ...

# %%
datana.isna().sum()
# Out:
# column_a    0
# column_b    0
# column_c    0
# column_d    0
# column_e    0
# column_f    0
# column_g    0
# column_h    0
# column_i    0
# column_j    0
# column_k    0
# column_l    0
# column_m    0
# column_n    0
# column_o    0
# column_p    0
# column_q    0
# column_r    0
# column_s    0
# column_t    0
# column_u    0
# column_v    0
# column_w    0
# column_x    0
# column_y    0
# column_z    0
# dtype: int64

# %%
len(datana)
# Out:
# 160

# %%
len(data)
# Out:
# 205

# %% [markdown]
# ---

# %%
data.head()
# Out:
#    column_a  column_b     column_c column_d column_e column_f     column_g  \
# 0         3       NaN  alfa-romero      gas      std      two  convertible
# 1         3       NaN  alfa-romero      gas      std      two  convertible
# 2         1       NaN  alfa-romero      gas      std      two    hatchback
# 3         2     164.0         audi      gas      std     four        sedan
# 4         2     164.0         audi      gas      std     four        sedan
#
#   column_h column_i  column_j  ...  column_q  column_r  column_s  column_t  \
# 0      rwd    front      88.6  ...       130      mpfi      3.47      2.68
# 1      rwd    front      88.6  ...       130      mpfi      3.47      2.68
# 2      rwd    front      94.5  ...       152      mpfi      2.68      3.47
# 3      fwd    front      99.8  ...       109      mpfi      3.19      3.40
# 4      4wd    front      99.4  ...       136      mpfi      3.19      3.40
#
#   column_u column_v  column_w column_x  column_y  column_z
# ...

# %%
#datafill = data     #["column_b"].fillna(15)

# %%
#datafill["column_b"].fillna(15,inplace=True)

# %%
#datafill.head()

# %%
data["column_b"].unique()
# Out:
# array([ nan, 164., 158., 192., 188., 121.,  98.,  81., 118., 148., 110.,
#        145., 137., 101.,  78., 106.,  85., 107., 104., 113., 150., 129.,
#        115.,  93., 142., 161., 153., 125., 128., 122., 103., 168., 108.,
#        194., 231., 119., 154.,  74., 186.,  83., 102.,  89.,  87.,  77.,
#         91., 134.,  65., 197.,  90.,  94., 256.,  95.])

# %%
mean  = data["column_b"].mean()

# %%
mean
# Out:
# 122.0

# %%
datafill = data

# %%
datafill["column_b"].fillna(mean,inplace=True)

# %%
datafill.head()
# Out:
#    column_a  column_b     column_c column_d column_e column_f     column_g  \
# 0         3     122.0  alfa-romero      gas      std      two  convertible
# 1         3     122.0  alfa-romero      gas      std      two  convertible
# 2         1     122.0  alfa-romero      gas      std      two    hatchback
# 3         2     164.0         audi      gas      std     four        sedan
# 4         2     164.0         audi      gas      std     four        sedan
#
#   column_h column_i  column_j  ...  column_q  column_r  column_s  column_t  \
# 0      rwd    front      88.6  ...       130      mpfi      3.47      2.68
# 1      rwd    front      88.6  ...       130      mpfi      3.47      2.68
# 2      rwd    front      94.5  ...       152      mpfi      2.68      3.47
# 3      fwd    front      99.8  ...       109      mpfi      3.19      3.40
# 4      4wd    front      99.4  ...       136      mpfi      3.19      3.40
#
#   column_u column_v  column_w column_x  column_y  column_z
# ...

# %%
datafill.dtypes
# Out:
# column_a      int64
# column_b    float64
# column_c     object
# column_d     object
# column_e     object
# column_f     object
# column_g     object
# column_h     object
# column_i     object
# column_j    float64
# column_k    float64
# column_l    float64
# column_m    float64
# column_n      int64
# column_o     object
# column_p     object
# column_q      int64
# column_r     object
# column_s    float64
# column_t    float64
# column_u    float64
# column_v    float64
# column_w    float64
# column_x      int64
# column_y      int64
# column_z    float64
# dtype: object

# %%
datafill.isna().sum()
# Out:
# column_a    0
# column_b    0
# column_c    0
# column_d    0
# column_e    0
# column_f    0
# column_g    0
# column_h    0
# column_i    0
# column_j    0
# column_k    0
# column_l    0
# column_m    0
# column_n    0
# column_o    0
# column_p    0
# column_q    0
# column_r    0
# column_s    4
# column_t    4
# column_u    0
# column_v    2
# column_w    2
# column_x    0
# column_y    0
# column_z    4
# dtype: int64

# %%
datafill["column_f"].value_counts()
# Out:
# four    114
# two      89
# ?         2
# Name: column_f, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,7))

datafill["column_d"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
x =  ["a","b","c","d","f","g"]

# %%
y = [34,21,4,12,54,90]

# %%
# Out:
# 114

# %%
plt.bar(datafill["column_f"],datafill["column_b"])
# Out:
# <BarContainer object of 205 artists>

# %%
plt.figure(figsize=(13,5))
datafill["column_c"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
datafill.describe()
# Out:
#          column_a    column_b    column_j    column_k    column_l    column_m  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146  122.000000   98.756585  174.049268   65.907805   53.724878
# std      1.245307   31.681008    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   65.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000  101.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000  122.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  137.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  256.000000  120.900000  208.100000   72.300000   59.800000
#
#           column_n    column_q    column_s    column_t    column_u  \
# count   205.000000  205.000000  201.000000  201.000000  205.000000
# mean   2555.565854  126.907317    3.329751    3.255423   10.142537
# ...

# %%
datafill.groupby(["column_v"]).column_z.describe()
# Out:
#           count          mean          std      min       25%      50%  \
# column_v
# 48.0        1.0   5151.000000          NaN   5151.0   5151.00   5151.0
# 52.0        2.0   7885.000000   155.563492   7775.0   7830.00   7885.0
# 55.0        1.0   7099.000000          NaN   7099.0   7099.00   7099.0
# 56.0        2.0   7843.000000    77.781746   7788.0   7815.50   7843.0
# 58.0        1.0   6479.000000          NaN   6479.0   6479.00   6479.0
# 60.0        1.0   5399.000000          NaN   5399.0   5399.00   5399.0
# 62.0        6.0   6961.333333  1216.135957   5348.0   6375.50   6703.0
# 64.0        1.0  10795.000000          NaN  10795.0  10795.00  10795.0
# 68.0       19.0   6965.421053  1934.682412   5195.0   6142.00   6669.0
# 69.0       10.0   7030.900000  1032.149047   5118.0   6699.00   7324.0
# 70.0        9.0   7628.444444   955.614738   6295.0   6938.00   7738.0
# 72.0        1.0  18344.000000          NaN  18344.0  18344.00  18344.0
# ...

# %%
import seaborn as sns

# %%
sns.boxplot(x="column_g",y = "column_z",data=datafill)
# Out:
# <AxesSubplot:xlabel='column_g', ylabel='column_z'>

# %%
df_re = datafill.groupby(["column_g"]).describe()
df_re.head()
# Out:
#             column_a                                                column_b  \
#                count      mean       std  min   25%  50%   75%  max    count
# column_g
# convertible      6.0  2.833333  0.408248  2.0  3.00  3.0  3.00  3.0      6.0
# hardtop          8.0  1.875000  0.991031  0.0  1.75  2.0  2.25  3.0      8.0
# hatchback       70.0  1.585714  1.109809 -1.0  1.00  1.0  3.00  3.0     70.0
# sedan           96.0  0.333333  0.991189 -2.0  0.00  0.0  1.00  2.0     96.0
# wagon           25.0 -0.160000  0.624500 -1.0 -1.00  0.0  0.00  1.0     25.0
#
#                          ... column_y       column_z                \
#                    mean  ...      75%   max    count          mean
# column_g                 ...
# convertible  127.333333  ...    28.50  30.0      6.0  21890.500000
# hardtop      128.625000  ...    30.00  37.0      8.0  22208.500000
# hatchback    130.642857  ...    38.00  54.0     68.0   9957.441176
# ...
